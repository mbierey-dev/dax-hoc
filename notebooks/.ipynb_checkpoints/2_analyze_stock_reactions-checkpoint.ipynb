# %%
# %cd ..
# Out:
# /Users/martinbierey/git/dax-hoc

# %%
from src.db import read_all
from IPython.display import display,HTML
import pandas as pd 
#pd.set_option('display.max_colwidth', None)
from notebooks.helpers import display_formatted_cell

# %%
dfs = read_all()
list(dfs)
# Out:
# ['companies',
#  'earnings_events',
#  'expectations_snapshots',
#  'feedback_reports',
#  'llm_runs',
#  'price_reactions',
#  'trade_decisions']

# %%
df = dfs['price_reactions'].copy()
df.head()
# Out:
#                                      id                     earnings_event_id  \
# 0  c1efd951-6396-4c76-864e-d7615fdf3b1d  9e92f110-1461-4108-835f-1911c9765586
#
#          ticker date_t_minus_1     date_t0  close_t_minus_1  close_t0  \
# 0  NL0010273215     2026-04-14  2026-04-15      1284.199951    1230.0
#
#    return_t0 benchmark_ticker  benchmark_close_t_minus_1  benchmark_close_t0  \
# 0  -0.042205          XDWD.DE                 124.919998          125.360001
#
#    benchmark_return_t0  abnormal_return_t0                  fetched_at
# 0             0.003522           -0.045728  2026-04-16 10:17:26.295766
